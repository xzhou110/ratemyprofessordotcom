# %%
import requests
import re
import time
import os
import pandas as pd
import pickle

from bs4 import BeautifulSoup
from IPython.core.display import display, HTML
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


#import diagnostic_plots
import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
% matplotlib inline
# Out:
# /Users/xzhou/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#save to pick for efficiency



filename_berkely = '/Users/xzhou/github/project_files/project_luther/professor_data_berkely.pkl' #3986 records
filename_nyu = '/Users/xzhou/github/project_files/project_luther/professor_data_nyu.pkl' #5607 records
filename_uf = '/Users/xzhou/github/project_files/project_luther/professor_data_uf.pkl' #5307 records

df_berkely=pd.read_pickle(filename_berkely)
df_nyu=pd.read_pickle(filename_nyu)
df_uf=pd.read_pickle(filename_uf)

# %%
print(df_berkely.shape)
print(df_nyu.shape)
print(df_uf.shape)
# Out:
# (3986, 24)
# (5607, 24)
# (5306, 24)

# %%
dfs=pd.concat([df_berkely, df_nyu, df_uf])

# %%
dfs.head()
# Out:
#             Name  Rating  Level of difficulty  Total reviews  \
# 0  Jerry Sanders     2.7                  3.4             75
# 1   Chris Dolder     4.8                  3.9              9
# 2   Bob Calonico     4.7                  1.6             29
# 3    Zack Powell     2.1                  3.0             15
# 4    Mary Kelsey     4.6                  1.6             63
#
#    Accessible outside class  Amazing lectures  Beware of pop quizzes  Caring  \
# 0                      0.00              0.00                    0.0    0.00
# 1                      0.00              0.00                    0.0    0.00
# 2                      0.05              0.00                    0.0    0.26
# 3                      0.00              0.00                    0.0    0.00
# 4                      0.04              0.04                    0.0    0.12
#
#    Clear grading criteria  Extra credit      ...       Hilarious  \
# 0                    0.00          0.00      ...            0.00
# 1                    0.00          0.00      ...            0.00
# 2                    0.00          0.00      ...            0.26
# 3                    0.00          0.00      ...            0.00
# 4                    0.08          0.27      ...            0.00
#
#    Inspirational  Lecture heavy  Lots of homework  Participation matters  \
# 0           0.00           0.00               0.0                   0.00
# 1           0.50           0.00               0.0                   0.00
# 2           0.32           0.00               0.0                   0.00
# 3           0.00           0.00               0.0                   0.00
# 4           0.08           0.04               0.0                   0.08
#
#    Respected  Skip class? you won't pass.  So many papers  Test heavy  \
# 0       0.00                         0.00             0.0         0.0
# 1       0.00                         0.00             0.0         0.0
# 2       0.11                         0.00             0.0         0.0
# 3       0.00                         0.00             0.0         0.0
# 4       0.12                         0.04             0.0         0.0
#
#    Tough grader
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.04
#
# [5 rows x 24 columns]

# %%
dfs.shape
# Out:
# (14899, 24)

# %%
#check for null
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14899 entries, 0 to 5305
# Data columns (total 24 columns):
# Name                           14899 non-null object
# Rating                         14899 non-null float64
# Level of difficulty            14899 non-null float64
# Total reviews                  14899 non-null int64
# Accessible outside class       14899 non-null float64
# Amazing lectures               14899 non-null float64
# Beware of pop quizzes          14899 non-null float64
# Caring                         14899 non-null float64
# Clear grading criteria         14899 non-null float64
# Extra credit                   14899 non-null float64
# Get ready to read              14899 non-null float64
# Gives good feedback            14899 non-null float64
# Graded by few things           14899 non-null float64
# Group projects                 14899 non-null float64
# Hilarious                      14899 non-null float64
# Inspirational                  14899 non-null float64
# Lecture heavy                  14899 non-null float64
# Lots of homework               14899 non-null float64
# Participation matters          14899 non-null float64
# Respected                      14899 non-null float64
# Skip class? you won't pass.    14899 non-null float64
# So many papers                 14899 non-null float64
# Test heavy                     14899 non-null float64
# Tough grader                   14899 non-null float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 2.8+ MB

# %%
dfs.head()
# Out:
#             Name  Rating  Level of difficulty  Total reviews  \
# 0  Jerry Sanders     2.7                  3.4             75
# 1   Chris Dolder     4.8                  3.9              9
# 2   Bob Calonico     4.7                  1.6             29
# 3    Zack Powell     2.1                  3.0             15
# 4    Mary Kelsey     4.6                  1.6             63
#
#    Accessible outside class  Amazing lectures  Beware of pop quizzes  Caring  \
# 0                      0.00              0.00                    0.0    0.00
# 1                      0.00              0.00                    0.0    0.00
# 2                      0.05              0.00                    0.0    0.26
# 3                      0.00              0.00                    0.0    0.00
# 4                      0.04              0.04                    0.0    0.12
#
#    Clear grading criteria  Extra credit      ...       Hilarious  \
# 0                    0.00          0.00      ...            0.00
# 1                    0.00          0.00      ...            0.00
# 2                    0.00          0.00      ...            0.26
# 3                    0.00          0.00      ...            0.00
# 4                    0.08          0.27      ...            0.00
#
#    Inspirational  Lecture heavy  Lots of homework  Participation matters  \
# 0           0.00           0.00               0.0                   0.00
# 1           0.50           0.00               0.0                   0.00
# 2           0.32           0.00               0.0                   0.00
# 3           0.00           0.00               0.0                   0.00
# 4           0.08           0.04               0.0                   0.08
#
#    Respected  Skip class? you won't pass.  So many papers  Test heavy  \
# 0       0.00                         0.00             0.0         0.0
# 1       0.00                         0.00             0.0         0.0
# 2       0.11                         0.00             0.0         0.0
# 3       0.00                         0.00             0.0         0.0
# 4       0.12                         0.04             0.0         0.0
#
#    Tough grader
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.04
#
# [5 rows x 24 columns]

# %%
# noted records with no name and no rating
dfs.tail()
# Out:
#                    Name  Rating  Level of difficulty  Total reviews  \
# 5301                        0.0                  2.5              0
# 5302                        0.0                  2.5              0
# 5303  Tina D'Allesandro     4.0                  3.0              1
# 5304          Kay Leary     5.0                  3.0              1
# 5305      Lisa Domenico     4.0                  5.0              1
#
#       Accessible outside class  Amazing lectures  Beware of pop quizzes  \
# 5301                       0.0               0.0                    0.0
# 5302                       0.0               0.0                    0.0
# 5303                       0.0               0.0                    0.0
# 5304                       0.0               0.0                    0.0
# 5305                       0.0               0.0                    0.0
#
#       Caring  Clear grading criteria  Extra credit      ...       Hilarious  \
# 5301     0.0                    0.00           0.0      ...             0.0
# 5302     0.0                    0.00           0.0      ...             0.0
# 5303     0.0                    0.00           0.0      ...             0.0
# 5304     0.0                    0.33           0.0      ...             0.0
# 5305     0.0                    0.00           0.0      ...             0.0
#
#       Inspirational  Lecture heavy  Lots of homework  Participation matters  \
# 5301            0.0            0.0               0.0                   0.00
# 5302            0.0            0.0               0.0                   0.00
# 5303            0.0            0.0               0.0                   0.33
# 5304            0.0            0.0               0.0                   0.00
# 5305            0.0            0.0               0.0                   0.33
#
#       Respected  Skip class? you won't pass.  So many papers  Test heavy  \
# 5301        0.0                          0.0             0.0         0.0
# 5273        0.0                          0.0             0.0         0.0
# 5274        0.0                          0.0             0.0         0.0
# 5275        0.0                          0.0             0.0         0.0
# 5278        0.0                          0.0             0.0         0.0
# 5279        0.0                          0.0             0.0         0.0
# 5282        0.0                          0.0             0.0         0.0
# 5285        0.0                          0.0             0.0         0.0
# 5286        0.0                          0.0             0.0         0.0
# 5287        0.0                          0.0             0.0         0.0
# 5288        0.0                          0.0             0.0         0.0
# 5289        0.0                          0.0             0.0         0.0
# 5291        0.0                          0.0             0.0         0.0
# 5294        0.0                          0.0             0.0         0.0
# 5295        0.0                          0.0             0.0         0.0
# 5296        0.0                          0.0             0.0         0.0
# 5297        0.0                          0.0             0.0         0.0
# 5298        0.0                          0.0             0.0         0.0
# 5299        0.0                          0.0             0.0         0.0
# 5300        0.0                          0.0             0.0         0.0
# 5301        0.0                          0.0             0.0         0.0
# 5302        0.0                          0.0             0.0         0.0
#
#       Tough grader
# 244            0.0
# 274            0.0
# 376            0.0
# 416            0.0
# 478            0.0
# 530            0.0
# 565            0.0
# 674            0.0
# 694            0.0
# 768            0.0
# 782            0.0
# 783            0.0
# 801            0.0
# 850            0.0
# 906            0.0
# 935            0.0
# 1035           0.0
# 1051           0.0
# 1067           0.0
# 1085           0.0
# 1105           0.0
# 1115           0.0
# 1128           0.0
# 1150           0.0
# 1227           0.0
# 1315           0.0
# 1390           0.0
# 1392           0.0
# 1393           0.0
# 1441           0.0
# ...            ...
# 5247           0.0
# 5253           0.0
# 5254           0.0
# 5263           0.0
# 5266           0.0
# 5268           0.0
# 5269           0.0
# 5270           0.0
# 5272           0.0
# 5273           0.0
# 5274           0.0
# 5275           0.0
# 5278           0.0
# 5279           0.0
# 5282           0.0
# 5285           0.0
# 5286           0.0
# 5287           0.0
# 5288           0.0
# 5289           0.0
# 5291           0.0
# 5294           0.0
# 5295           0.0
# 5296           0.0
# 5297           0.0
# 5298           0.0
# 5299           0.0
# 5300           0.0
# 5301           0.0
# 5302           0.0
#
# [1661 rows x 24 columns]

# %%
dfs_smaller=dfs[dfs.Name!=""]
dfs_smaller.shape
# Out:
# (13238, 24)

# %%
# no constant

model=sm.OLS(df.iloc[:,1], df.iloc[:,2:])
fit=model.fit()
fit.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-ccf840b85b7a> in <module>()
#       1 # no constant
#       2
# ----> 3 model=sm.OLS(df.iloc[:,1], df.iloc[:,2:])
#       4 fit=model.fit()
#       5 fit.summary()
#
# NameError: name 'df' is not defined

# %%
# no constant

model=sm.OLS(df_smaller.iloc[:,1], df_smaller.iloc[:,2:])
fit=model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.842
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     840.9
# Date:                Sun, 15 Jul 2018   Prob (F-statistic):               0.00
# Time:                        03:45:44   Log-Likelihood:                -6532.4
# No. Observations:                3500   AIC:                         1.311e+04
# Df Residuals:                    3478   BIC:                         1.324e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Level of difficulty             1.0761      0.012     87.533      0.000       1.052       1.100
# Total reviews                   0.0040      0.001      2.756      0.006       0.001       0.007
# Accessible outside class        0.1235      0.390      0.317      0.751      -0.641       0.888
# Amazing lectures                1.7132      0.301      5.694      0.000       1.123       2.303
# Beware of pop quizzes          -1.1987      0.844     -1.421      0.156      -2.853       0.456
# Caring                          1.8720      0.267      7.004      0.000       1.348       2.396
# Clear grading criteria          1.6503      0.353      4.677      0.000       0.959       2.342
# Extra credit                    1.4486      0.709      2.044      0.041       0.059       2.838
# Get ready to read              -0.3770      0.252     -1.496      0.135      -0.871       0.117
# Gives good feedback             1.5934      0.279      5.710      0.000       1.046       2.141
# Graded by few things           -0.7797      0.411     -1.899      0.058      -1.585       0.025
# Group projects                 -0.1175      0.475     -0.247      0.805      -1.050       0.815
# Hilarious                       1.3607      0.337      4.033      0.000       0.699       2.022
# Inspirational                   1.7140      0.321      5.333      0.000       1.084       2.344
# Lecture heavy                  -0.1146      0.299     -0.384      0.701      -0.700       0.471
# Lots of homework               -0.5534      0.383     -1.447      0.148      -1.304       0.197
# Participation matters           1.4798      0.305      4.845      0.000       0.881       2.079
# Respected                       1.3532      0.300      4.506      0.000       0.764       1.942
# Skip class? you won't pass.    -0.5273      0.347     -1.521      0.128      -1.207       0.152
# So many papers                 -1.7406      0.761     -2.288      0.022      -3.232      -0.249
# Test heavy                     -2.5402      0.560     -4.538      0.000      -3.638      -1.443
# Tough grader                   -2.2487      0.248     -9.054      0.000      -2.736      -1.762
# ==============================================================================
# Omnibus:                       30.004   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.938
# Skew:                          -0.211   Prob(JB):                     1.91e-07
# Kurtosis:                       3.182   Cond. No.                         697.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# added constant
model2=sm.OLS(dfs_smaller.iloc[:,1], sm.add_constant(dfs_smaller.iloc[:,2:]))
fit2=model2.fit()
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.274
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     227.0
# Date:                Sun, 15 Jul 2018   Prob (F-statistic):               0.00
# Time:                        18:10:55   Log-Likelihood:                -17092.
# No. Observations:               13238   AIC:                         3.423e+04
# Df Residuals:                   13215   BIC:                         3.440e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           4.7979      0.027    177.185      0.000       4.745       4.851
# Level of difficulty            -0.3692      0.009    -41.736      0.000      -0.387      -0.352
# Total reviews                  -0.0015      0.000     -3.563      0.000      -0.002      -0.001
# Accessible outside class        1.0276      0.125      8.189      0.000       0.782       1.274
# Amazing lectures                1.3608      0.098     13.954      0.000       1.170       1.552
# Beware of pop quizzes          -0.5748      0.209     -2.748      0.006      -0.985      -0.165
# Caring                          0.7060      0.079      8.940      0.000       0.551       0.861
# Clear grading criteria          0.3974      0.099      4.003      0.000       0.203       0.592
# Extra credit                    0.0623      0.161      0.386      0.699      -0.254       0.378
# Get ready to read              -0.2965      0.078     -3.793      0.000      -0.450      -0.143
# Gives good feedback             1.0619      0.078     13.638      0.000       0.909       1.215
# Graded by few things           -1.3339      0.129    -10.367      0.000      -1.586      -1.082
# Group projects                 -0.7761      0.137     -5.681      0.000      -1.044      -0.508
# Hilarious                       0.4803      0.105      4.559      0.000       0.274       0.687
# Inspirational                   0.7593      0.101      7.502      0.000       0.561       0.958
# Lecture heavy                  -0.9668      0.092    -10.515      0.000      -1.147      -0.787
# Lots of homework               -0.5933      0.100     -5.916      0.000      -0.790      -0.397
# Participation matters           0.2306      0.085      2.711      0.007       0.064       0.397
# Respected                       0.8668      0.088      9.904      0.000       0.695       1.038
# Skip class? you won't pass.    -0.0257      0.096     -0.267      0.790      -0.215       0.163
# So many papers                 -1.3531      0.198     -6.828      0.000      -1.742      -0.965
# Test heavy                     -1.1100      0.184     -6.024      0.000      -1.471      -0.749
# Tough grader                   -0.9288      0.073    -12.807      0.000      -1.071      -0.787
# ==============================================================================
# Omnibus:                      886.518   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1079.856
# Skew:                          -0.664   Prob(JB):                    3.25e-235
# Kurtosis:                       3.440   Cond. No.                         584.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# added constant
model2=sm.OLS(df_smaller.iloc[:,1], sm.add_constant(df_smaller.iloc[:,2:]))
fit2=model2.fit()
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     51.38
# Date:                Sun, 15 Jul 2018   Prob (F-statistic):          1.69e-193
# Time:                        03:45:10   Log-Likelihood:                -4523.5
# No. Observations:                3500   AIC:                             9093.
# Df Residuals:                    3477   BIC:                             9235.
# Df Model:                          22
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           4.7763      0.055     86.495      0.000       4.668       4.885
# Level of difficulty            -0.3545      0.018    -19.768      0.000      -0.390      -0.319
# Total reviews                  -0.0024      0.001     -2.915      0.004      -0.004      -0.001
# Accessible outside class        0.6741      0.220      3.068      0.002       0.243       1.105
# Amazing lectures                1.4641      0.170      8.636      0.000       1.132       1.797
# Beware of pop quizzes          -0.3985      0.475     -0.838      0.402      -1.331       0.534
# Caring                          0.6502      0.151      4.299      0.000       0.354       0.947
# Clear grading criteria          0.3173      0.199      1.592      0.112      -0.074       0.708
# Extra credit                   -0.3491      0.400     -0.873      0.383      -1.133       0.435
# Get ready to read              -0.2663      0.142     -1.876      0.061      -0.545       0.012
# Gives good feedback             0.9701      0.157      6.163      0.000       0.661       1.279
# Graded by few things           -1.5537      0.231     -6.712      0.000      -2.008      -1.100
# Group projects                 -0.7251      0.268     -2.706      0.007      -1.250      -0.200
# Hilarious                       0.1609      0.191      0.844      0.399      -0.213       0.535
# Inspirational                   0.6503      0.181      3.583      0.000       0.294       1.006
# Lecture heavy                  -0.7216      0.168     -4.287      0.000      -1.052      -0.392
# Lots of homework               -0.1637      0.216     -0.760      0.448      -0.586       0.259
# Participation matters           0.3064      0.173      1.775      0.076      -0.032       0.645
# Respected                       0.8378      0.169      4.949      0.000       0.506       1.170
# Skip class? you won't pass.     0.2473      0.196      1.265      0.206      -0.136       0.631
# So many papers                 -2.5961      0.429     -6.056      0.000      -3.437      -1.756
# Test heavy                     -1.3147      0.316     -4.165      0.000      -1.934      -0.696
# Tough grader                   -0.8681      0.141     -6.165      0.000      -1.144      -0.592
# ==============================================================================
# Omnibus:                      254.245   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              312.130
# Skew:                          -0.695   Prob(JB):                     1.67e-68
# Kurtosis:                       3.454   Cond. No.                         697.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# 'Beware of pop quizzes','Get ready to read','Graded by few things','Group projects','Lecture heavy', 'Lots of homework','Skip class? you won't pass.',

subset=['Rating','Level of difficulty', 'Total reviews',
       'Accessible outside class', 'Amazing lectures', 
       'Caring', 'Clear grading criteria', 'Extra credit', 
       'Gives good feedback',  
       'Hilarious', 'Inspirational', 
       'Participation matters', 'Respected', 
       'So many papers', 'Test heavy', 'Tough grader']

# %%
df_drill_down=df[subset]
df_drill_down.shape
# Out:
# (3986, 16)

# %%
df_drill_down.iloc[:,0:3].head(20)
# Out:
#     Rating  Level of difficulty  Total reviews
# 0      2.7                  3.4             75
# 1      4.8                  3.9              9
# 2      4.7                  1.6             29
# 3      2.1                  3.0             15
# 4      4.6                  1.6             63
# 5      3.6                  3.1             47
# 6      4.4                  3.3            143
# 7      2.9                  3.0             61
# 8      4.4                  2.2             25
# 9      2.8                  3.0             39
# 10     4.2                  3.5             32
# 11     4.1                  2.7             22
# 12     5.0                  1.8             14
# 13     3.9                  2.8             47
# 14     3.6                  2.9             33
# 15     4.5                  2.6            237
# 16     3.6                  3.4             10
# 17     2.3                  2.3              3
# 18     4.4                  3.3             43
# 19     4.3                  3.7             10

# %%
# no constant

model3=sm.OLS(df_drill_down.iloc[:,0], df_drill_down.iloc[:,1:])
fit3=model3.fit()
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     977.2
# Date:                Sun, 15 Jul 2018   Prob (F-statistic):               0.00
# Time:                        03:32:43   Log-Likelihood:                -7773.9
# No. Observations:                3986   AIC:                         1.558e+04
# Df Residuals:                    3971   BIC:                         1.567e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Level of difficulty          0.9081      0.012     76.641      0.000       0.885       0.931
# Total reviews                0.0094      0.002      6.087      0.000       0.006       0.012
# Accessible outside class     0.6488      0.422      1.536      0.125      -0.179       1.477
# Amazing lectures             2.1108      0.326      6.484      0.000       1.473       2.749
# Caring                       2.2600      0.290      7.798      0.000       1.692       2.828
# Clear grading criteria       1.9625      0.381      5.154      0.000       1.216       2.709
# Extra credit                 1.7599      0.767      2.294      0.022       0.256       3.264
# Gives good feedback          2.0945      0.302      6.935      0.000       1.502       2.687
# Hilarious                    1.6223      0.366      4.431      0.000       0.904       2.340
# Inspirational                2.0550      0.349      5.894      0.000       1.371       2.739
# Participation matters        1.8749      0.327      5.730      0.000       1.233       2.516
# Respected                    1.7308      0.326      5.315      0.000       1.092       2.369
# So many papers              -1.2436      0.818     -1.521      0.128      -2.847       0.360
# Test heavy                  -1.9726      0.604     -3.267      0.001      -3.157      -0.789
# Tough grader                -1.6175      0.263     -6.155      0.000      -2.133      -1.102
# ==============================================================================
# Omnibus:                      191.549   Durbin-Watson:                   1.792
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.585
# Skew:                          -0.022   Prob(JB):                     1.42e-17
# Kurtosis:                       2.318   Cond. No.                         621.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_drill_down.corr()
# Out:
#                             Rating  Level of difficulty  Total reviews  \
# Rating                    1.000000            -0.070883       0.128984
# Level of difficulty      -0.070883             1.000000       0.082905
# Total reviews             0.128984             0.082905       1.000000
# Accessible outside class  0.120350             0.069079       0.075581
# Amazing lectures          0.211491             0.036358       0.148009
# Caring                    0.197440            -0.022073       0.053148
# Clear grading criteria    0.108328            -0.017506       0.084102
# Extra credit              0.050867            -0.030605       0.028156
# Gives good feedback                    0.197829   0.196307        0.011396
# Hilarious                              0.015744   0.115639        0.002208
# Inspirational                          0.065626   0.263821       -0.000854
# Participation matters                  1.000000   0.060387        0.022962
# Respected                              0.060387   1.000000        0.000638
# So many papers                         0.022962   0.000638        1.000000
# Test heavy                            -0.001159   0.004183        0.026544
# Tough grader                           0.009658   0.014183        0.094447
#
#                           Test heavy  Tough grader
# Rating                     -0.029653     -0.029954
# Level of difficulty         0.105554      0.227797
# Total reviews               0.076740      0.107471
# Accessible outside class    0.026243      0.004586
# Amazing lectures            0.007168      0.009717
# Caring                     -0.005961      0.001856
# Clear grading criteria      0.058347      0.012895
# Extra credit                0.010283      0.002531
# Gives good feedback        -0.020963      0.027196
# Hilarious                   0.020469      0.035241
# Inspirational              -0.006516      0.009729
# Participation matters      -0.001159      0.009658
# Respected                   0.004183      0.014183
# So many papers              0.026544      0.094447
# Test heavy                  1.000000      0.107527
# Tough grader                0.107527      1.000000

# %%
sns.pairplot(df_drill_down, size = 2, aspect=1.5);

# %%
fit.resid.plot(style='o', figsize=(12,8));

# %%
#diagnostic_plots.diagnostic_plots(df_drill_down.drop('rating', axis=1), df_drill_down['rating'], fit1)

# %%
lr=LinearRegression()
X=df.iloc[:,2:]
y=df.iloc[:,1]
lr.fit(X, y)
lr.score(X, y)
# Out:
# 0.14469202385101765

# %%
# import PolynomialFeatures and make_pipeline for Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Plot the results of a pipeline against ground truth and actual data
def plot_approximation(est, ax, label=None):
    """Plot the approximation of ``est`` on axis ``ax``. """
    #ax.plot(x_plot, f(x_plot), label='ground truth', color='green')
    ax.scatter(X, y)
    #ax.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red', label=label)
    ax.set_ylim((-2, 2))
    ax.set_xlim((0, 1))
    ax.set_ylabel('y')
    ax.set_xlabel('x')
    ax.legend(loc='upper right',frameon=True)

# %%
# Step through degrees from 0 to 9 and store the training and test (generalization) error.
# This sets up 5 rows of 2 plots each (KEEP)
fig, ax_rows = plt.subplots(5, 2, figsize=(15, 20))
for degree in range(10):
    est = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    est.fit(X, y)
    # This sets the appropriate axis for each degree (KEEP)
    ax_row_left, ax_row_right = ax_rows[degree//2]
    if degree%2 == 0:
        ax = ax_row_left
    else:
        ax = ax_row_right
    plot_approximation(est, ax, label='degree=%d' % degree)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3d5ed723ade3> in <module>()
#      11     else:
#      12         ax = ax_row_right
# ---> 13     plot_approximation(est, ax, label='degree=%d' % degree)
#
# <ipython-input-24-b32172d1e66f> in plot_approximation(est, ax, label)
#       7     """Plot the approximation of ``est`` on axis ``ax``. """
#       8     #ax.plot(x_plot, f(x_plot), label='ground truth', color='green')
# ----> 9     ax.scatter(X, y)
#      10     #ax.plot(x_plot, est.predict(x_plot[:, np.newaxis]), color='red', label=label)
#      11     ax.set_ylim((-2, 2))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4241         y = np.ma.ravel(y)
#    4242         if x.size != y.size:
# -> 4243             raise ValueError("x and y must be the same size")
#    4244
#    4245         if s is None:
#
# ValueError: x and y must be the same size

# %%
dfs['Rating'].hist()
